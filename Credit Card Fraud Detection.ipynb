# %% [markdown]
# # Steps

# %%
Credit Card Data
Data Pre Processing
Data Analysis 
Train Test Split
Logistic Regression Model
Evaluation

# %%
import numpy as np  # for array
import pandas as pd  # for CSV file
from sklearn.model_selection import train_test_split  # fixed typo: trian_test_split to train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score  # fixed typo: acccuracy_score to accuracy_score

# %%
# LOad the Dataset to a pandas DataFrame

# %%
credit_card_data = pd.read_csv("C:/Users\pc/Downloads/creditcard.csv")

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
# Dataset information

credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Check the numbre of missig values in each columns
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Distribution of legit transection & fraudulent transection
credit_card_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# 0 is for normal transection
# 1 is for Fraud transection

# %%
This data is highly unbalanced

# %%
# Sepration the data for analysis
legit = credit_card_data[credit_card_data.Class==0]
fraud = credit_card_data[credit_card_data.Class==1]

# %%
fraud.sample(4)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 163149  115691.0 -1.550273  1.088689 -2.393388  1.008733 -1.087562 -1.104602
# 6529      7891.0 -1.585505  3.261585 -4.137422  2.357096 -1.405043 -1.879437
# 150644   93823.0 -3.821939  5.667247 -9.244963  8.246147 -4.368286 -3.450735
# 221018  142394.0 -3.367770  0.099249 -6.148487  3.401955  0.458307 -1.571630
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 163149 -2.670503  0.147655 -0.978626  ...  0.802316  1.037105  0.095815
# 6529   -3.513687  1.515607 -1.207166  ...  0.501543 -0.546869 -0.076584
# 150644 -8.427378  2.305609 -5.338079  ...  1.990520  0.083353 -0.062264
# 221018 -1.358708  0.672409 -3.188001  ...  0.861308  1.249301  1.850627
#
#              V24       V25       V26       V27       V28  Amount  Class
# 163149 -0.320191 -0.080731  0.091012  0.024928 -0.077820   17.06      1
# 6529   -0.425550  0.123644  0.321985  0.264028  0.132817    1.00      1
# ...

# %%
legit.shape, fraud.shape
# Out:
# ((284315, 31), (492, 31))

# %%
# Statistical measure of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Compare the vslues for both Transection
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Under-Sampling

# %%
Build a sample dataset containing similiar distribution of normal tracsection and fraudulent trasection

# %%
Number of Fraud Trasection --> 492

# %%
legit_sample = legit.sample(n=492)

# %%
legit_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 5090      4750.0  0.777169 -1.994312  0.589949 -0.830422 -1.933360 -0.456433
# 138994   82959.0  0.367792 -1.778118  0.675637  0.413932 -1.435336  0.518833
# 70828    54035.0 -2.010678  1.687707  1.456986  2.986080  0.653375  2.181894
# 167602  118787.0 -0.056186  0.995471 -0.604549 -0.760892  1.253614 -0.254902
# 38275    39323.0 -0.268185  0.663804 -0.142915 -1.171492  2.572565  3.354492
# ...          ...       ...       ...       ...       ...       ...       ...
# 38928    39619.0  1.130177 -0.177947 -1.502341  0.257131  2.273833  3.430440
# 179719  124211.0  1.893322  0.307675  0.016388  3.671156  0.028854  0.611582
# 91898    63675.0  1.245674  0.166975  0.488306  0.635322 -0.562777 -1.011073
# 256087  157533.0 -0.211175  1.161422 -0.968063 -1.436103  2.150716 -0.950720
# 149345   91055.0  2.079134  0.171764 -1.855045  0.645674  0.507200 -1.445819
#
# ...

# %%
# Concatenate two dataframe
# axis 0 for all the fraud values will be added below legit.sample row bise
# axis 1 for will the column bise

new_dataset = pd.concat([legit_sample,fraud], axis=0)

# %%
new_dataset.head(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 5090      4750.0  0.777169 -1.994312  0.589949 -0.830422 -1.933360 -0.456433
# 138994   82959.0  0.367792 -1.778118  0.675637  0.413932 -1.435336  0.518833
# 70828    54035.0 -2.010678  1.687707  1.456986  2.986080  0.653375  2.181894
# 167602  118787.0 -0.056186  0.995471 -0.604549 -0.760892  1.253614 -0.254902
# 38275    39323.0 -0.268185  0.663804 -0.142915 -1.171492  2.572565  3.354492
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 5090   -0.773586 -0.238074 -0.549448  ... -0.260507 -0.888328 -0.043090
# 138994 -0.381780  0.294869  1.051505  ...  0.070997 -0.475752 -0.236254
# 70828  -0.535974 -1.043083 -0.518988  ...  1.135396 -0.816920  0.575746
# 167602  0.919160 -0.018718 -0.317971  ... -0.299454 -0.735255  0.107850
# 38275   0.169213  0.845416 -0.642390  ...  0.101491  0.158730 -0.240606
#
# ...

# %%
new_dataset.tail(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95490.172764 -0.112112  0.031182 -0.025251 -0.063775 -0.004075
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.050863 -0.034183  0.010038  0.112908  ...  0.007665  0.042004
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.022616 -0.010034  0.007773 -0.006460 -0.006737 -0.004518  0.001603
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.394797
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# We can see that the mean value for V1 for Fraulent and Legit trasection is same as before when we campare the total legit and
Fraud and now

# 1st compare the all data and find its mean where fraud data is 492 and legit data 284315
# 2nd comare the data where fraud is 492 and legit is 392
 but the data differnt is same for both condition and the diff is the same between fraud and legit

# %%
x=new_dataset.drop(columns = 'Class', axis = 1)
y=new_dataset['Class']

# %%
x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 5090      4750.0  0.777169 -1.994312  0.589949 -0.830422 -1.933360 -0.456433
# 138994   82959.0  0.367792 -1.778118  0.675637  0.413932 -1.435336  0.518833
# 70828    54035.0 -2.010678  1.687707  1.456986  2.986080  0.653375  2.181894
# 167602  118787.0 -0.056186  0.995471 -0.604549 -0.760892  1.253614 -0.254902
# 38275    39323.0 -0.268185  0.663804 -0.142915 -1.171492  2.572565  3.354492
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y
# Out:
# 5090      0
# 138994    0
# 70828     0
# 167602    0
# 38275     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
Split thw data into Training and Testing Data

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, stratify = y, random_state = 2)

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Logistic Regression

# %%
# Trianig the Logistic Regression Model with Training Data

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# #### Accurace Score

# %%
# Accuracy on Training Data
x_train_predition = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_predition , y_train)

# %%
print('Accuracy on Training Data:' ,training_data_accuracy)
# Out:
# Accuracy on Training Data: 0.9161372299872935

# %%
# Accuracy score on Testing data
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print('Accuracy on Testing Data:' , test_data_accuracy)
# Out:
# Accuracy on Testing Data: 0.9035532994923858

# %%
# Accurcy score of Training data and Testing data is similiar
# If there is lots of diff in Training data and Testing Data than it is called over fitted and under fitted.
# Model is Over fitted if Training accuracy is 92% and the Testing accuracy is 50%
